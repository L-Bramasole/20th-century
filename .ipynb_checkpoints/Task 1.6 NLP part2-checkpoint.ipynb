# %% [markdown]
# # Advanced Data mining NLP NER

# %%
import pandas as pd 
import numpy as np
import spacy
from spacy import displacy
import networkx as nx
import os
import matplotlib.pyplot as plt
import scipy
import re

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\analy\anaconda3\envs\century_env\python.exe

# %%
# !C:\Users\analy\anaconda3\envs\century_env\python.exe -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      --- ------------------------------------ 1.0/12.8 MB 6.3 MB/s eta 0:00:02
#      --------- ------------------------------ 3.1/12.8 MB 8.0 MB/s eta 0:00:02
#      ----------------- ---------------------- 5.5/12.8 MB 9.3 MB/s eta 0:00:01
#      --------------------------- ------------ 8.9/12.8 MB 11.3 MB/s eta 0:00:01
#      ------------------------------------ -- 12.1/12.8 MB 12.0 MB/s eta 0:00:01
#      ---------------------------------------- 12.8/12.8 MB 11.5 MB/s  0:00:01
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.8.0
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %% [markdown]
# spaCy itself is just the NLP engine.
# To actually process text — tokenize, tag parts of speech, recognize entities — it needs a language model.
#
# en_core_web_sm is the small English model.

# %%
# Load spacy English module

NER = spacy.load("en_core_web_sm")

# %% [markdown]
# # Load 20th century key events txt

# %% [markdown]
# Here we will use NER spaCy NLP modern method that
# tokenizes
#
# lemmatizes
#
# identifies named entities (PERSON, ORG, GPE, etc.)
#
# splits sentences
#
# extracts relationships
#
# Note: both TextBlob(manuel method togerther with other manuel cleaning) and NER spaCy need the txt file as input after it is being scraped and converted from html to txt.

# %%
# Load the scraped text

with open('key_events_20th_century.txt', 'r', errors='ignore') as file:
    data = file.read().replace('\n', '')

# %%
data_NER = NER(data) # Extracts named entities (PERSON, ORG, GPE, DATE, etc.)

# %%
# Visualize identified entities

displacy.render(data_NER[273:20000], style = "ent", jupyter = True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">the century[edit]Main article:
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Edwardian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  eraMap of colonial and land-based empires throughout the world in
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1914The
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  new beginning of
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the 20th century
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  marked significant changes.
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The 1900s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  saw
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the decade
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  herald a series of inventions, including theautomobile,airplaneandradio broadcasting.
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1914
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  saw the completion of
# <mark class="entity" style="background: #9cc9cc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     thePanama Canal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
# .
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     TheScramble
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  for Africacontinued in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the 1900s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  and resulted in wars and genocide across the continent. Theatrocities in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Congo Free Stateshocked
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  the civilized world.From
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1914 to 1918
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the First World War
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
# , and its aftermath, caused major changes in the power balance of the world, destroying or transforming some of the most powerful empires.&quot;The war to end all wars&quot;:
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     World War I
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
#  (
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1914â€“1918)[edit]Main
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  article:
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     World War IArrest
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
#  of a suspect in
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sarajevofollowing theAssassination
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Archduke Franz FerdinandThe First World War
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  (or simply
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     WWI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# ), termed &quot;
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Great War
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
# &quot; by contemporaries, started in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     July 1914
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  and ended in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     November 1918
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# . The war was precipitated by theAssassination in Sarajevoof theAustro-Hungarian Empire's heir to the throne,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ErzherzogFranz Ferdinand
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , byGavrilo
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Princip
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left:

# %% [markdown]
# after scraping, some data wrangeling and cleaning were performed and then the txt file was saved to be ready for any NLP like NER.
#
# lowercase to be compatible with the scraped list of countries later should be done for the Entities later and not for the original text before NER.

# %% [markdown]
# # Get named entity list per sentence

# %%
df_sentences = [] # empty shell to store results

# Loop through sentences, get entity list for each sentence
for sent in data_NER.sents:
    entity_list = [ent.text for ent in sent.ents]
    df_sentences.append({"sentence": sent, "entities": entity_list})
    
df_sentences = pd.DataFrame(df_sentences)

# %%
df_sentences
# Out:
#                                               sentence  \
# 0    (Jump, to, contentMain, menuMain, menumove, to...
# 1    (Color(beta)AutomaticLightDarkThis, page, is, ...
# 2    (DonateCreate, accountLog, inPersonal, toolsDo...
# 3    (Overlord1.4.6Final, days1.4.7The, war, in, th...
# 4    (Edit, linksArticleTalkEnglishReadEditView, hi...
# ..                                                 ...
# 900  (p., Â,  , 600.ISBN978, -, 0, -, 415, -, 09311...
# 901  (The, 20th, Century, Research, Project(archive...
# 902  (By, using, this, site, ,, you, agree, to, the...
# 903  (WikipediaÂ, ®, is, a, registered, trademark, ...
# 904  (Privacy, policyAbout, WikipediaDisclaimersCon...
#
#                                               entities
# 0                                               [Jump]
# 1                                                   []
# 2    [sidebarhide(Top)1Historic, 20th, Historic, th...
# 3    [Holocaust1.4.12The Nuclear Age begins1.5The, ...
# 4    [URLDownload QR, PDFPrintable, CommonsWikidata...
# ..                                                 ...
# 900  [600.ISBN978, links[edit]Wikimedia Commons, th...
# 901  [20th, 26, February, February, the 20th Centur...
# 902                                                 []
# 903       [WikipediaÂ®, theWikimedia Foundation, Inc.]
# 904                                             [20th]
#
# [905 rows x 2 columns]

# %% [markdown]
# ## Load countries scraped list.txt

# %%
# Import the Scraped countires list txt file from task1.4

with open("Scraped List of Countries.txt", "r", encoding="utf-8") as f:
    countries = [line.strip() for line in f.readlines() if line.strip()]

# %%
# IMPORTANT!! here i am extending the countires list manually to include the old countries names
# this have to match the 20th century names for the lookup step later
countries.extend([
    "soviet union",
    "ussr",
    "yugoslavia",
    "czechoslovakia",
    "east germany",
    "west germany",
    "persia",
    "ottoman empire"
])

# %%
# Step 2: Convert list to DataFrame
countries_df = pd.DataFrame(countries, columns=["Country"])
countries_df
# Out:
#             Country
# 0             aruba
# 1       afghanistan
# 2            angola
# 3          anguilla
# 4     åland islands
# ..              ...
# 252  czechoslovakia
# 253    east germany
# 254    west germany
# 255          persia
# 256  ottoman empire
#
# [257 rows x 1 columns]

# %% [markdown]
# # Filtering entities from the data_NER

# %%
# lowercase the Entities first to match the lowercase in countries_df
df_sentences["entities"] = df_sentences["entities"].apply(
    lambda ents: [e.lower() for e in ents]
)

# %%
# Defining a function to filter out entities not of interest
# similar to xlookup in excel. ent_list will be the extracted enteties for each sentence

def filter_entity(ent_list, countries_df):
    return [ent for ent in ent_list 
            if ent in list(countries_df['Country'])]

# %%
# here the function will be applied
df_sentences['countries_entities'] = df_sentences['entities'].apply(
    lambda x: filter_entity(x, countries_df)
)

# %%
df_sentences.head(10)
# Out:
#                                             sentence  \
# 0  (Jump, to, contentMain, menuMain, menumove, to...
# 1  (Color(beta)AutomaticLightDarkThis, page, is, ...
# 2  (DonateCreate, accountLog, inPersonal, toolsDo...
# 3  (Overlord1.4.6Final, days1.4.7The, war, in, th...
# 4  (Edit, linksArticleTalkEnglishReadEditView, hi...
# 5  (TheWorld, Warssparked, tension, between, coun...
# 6  (These, advancements, have, played, a, signifi...
# 7  (Historic, events, in, the, 20th, century[edit...
# 8  (The, 1900s, saw, the, decade, herald, a, seri...
# 9  (1914, saw, the, completion, of, thePanama, Ca...
#
#                                             entities countries_entities
# 0                                             [jump]                 []
# 1                                                 []                 []
# 2  [sidebarhide(top)1historic, 20th, historic, th...                 []
# 3  [holocaust1.4.12the nuclear age begins1.5the, ...                 []
# 4  [urldownload qr, pdfprintable, commonswikidata...                 []
# 5       [theworld warssparked, theworld wide webwas]                 []
# 6                                            [today]                 []
# 7   [the 20th, edwardian, 1914the, the 20th century]                 []
# 8                            [the 1900s, the decade]                 []
# 9                            [1914, thepanama canal]                 []

# %%
# Filter out rows where the countries_entities is 0 or empty with naming filtered df

df_sentences_filtered = df_sentences[df_sentences['countries_entities'].map(len) > 0]

df_sentences_filtered.tail(10)
# Out:
#                                               sentence  \
# 548  (Glass, (, 14, August, 2018)."Hirohito, accept...
# 577  (Perspectives, in, Clinical, Research.2(2):72â...
# 639  (Past, &, Present(210):103â€“120.doi:10.1093, ...
# 653  (Retrieved20, December2018.^McQuade, ,, Joseph...
# 656  (December2018.^Henderson, ,, Barney, (, 15, Au...
# 662  (Retrieved18, December2018.^"The, Philippines,...
# 678  (", Colonial, Cartographies, ,, Postcolonial, ...
# 699  (Retrieved20, December2018.^King, ,, Charles, ...
# 881  (The, Journal, of, Politics.78(1):311â€“325.do...
# 882  (Singapore, :, World, Scientific.doi:10.1142/7...
#
#                                               entities  \
# 548  [glass, 14 august, 2018)."hirohito, japan, aug...
# 577                                           [israel]
# 639  [past & present(210):103â€“120.doi:10.1093/pas...
# 653                          [joseph, november, india]
# 656  [barney, 15, august, partition between india, ...
# 662  [philippines, 1898â€“1946, us house of represe...
# 678  [colonial cartographies, postcolonial borders,...
# 699  [charles, 2000).the, moldovans, romania, russi...
# 881  [the journal of politics.78(1):311â€“325.doi:1...
# 882                   [singapore, south korean, meet"]
#
#           countries_entities
# 548                  [japan]
# 577                 [israel]
# 639                [germany]
# 653                  [india]
# 656               [pakistan]
# 662            [philippines]
# 678  [afghanistan, pakistan]
# 699                [romania]
# 881                  [india]
# 882              [singapore]

# %% [markdown]
# no furthere wrangeling is needed

# %% [markdown]
# # Create Relationships

# %%
# Defining relationships 

# window size = 5 : this defines how many sentences will be looked at simultaneously 
relationships = [] # create an empty list

for i in range(df_sentences_filtered.index[-1]):
    end_i = min(i+5, df_sentences_filtered.index[-1])
    country_list = sum((df_sentences_filtered.loc[i: end_i].countries_entities), [])
    
    # Remove duplicated characters that are next to each other
    country_unique = [country_list[i] for i in range(len(country_list)) 
                   if (i==0) or country_list[i] != country_list[i-1]]
    
    if len(country_unique) > 1:
        for idx, a in enumerate(country_unique[:-1]):
            b = country_unique[idx + 1]
            relationships.append({"source": a, "target": b})

# %%
relationship_df = pd.DataFrame(relationships)

# %%
relationship_df
# Out:
#       source     target
# 0     france    germany
# 1     france    germany
# 2     france    germany
# 3     france    germany
# 4    germany      italy
# ..       ...        ...
# 433    india  singapore
# 434    india  singapore
# 435    india  singapore
# 436    india  singapore
# 437    india  singapore
#
# [438 rows x 2 columns]

# %%
# replace the names "ussr" with "soviet union" to have uniform name
relationship_df = relationship_df.replace("ussr", "soviet union")

# %%
# Sort the cases with a->b and b->a

relationship_df = pd.DataFrame(np.sort(relationship_df.values, axis = 1), columns = relationship_df.columns)
relationship_df.head(5)
# Out:
#     source   target
# 0   france  germany
# 1   france  germany
# 2   france  germany
# 3   france  germany
# 4  germany    italy

# %%
# Summarize the interactions

relationship_df["value"] = 1
relationship_df_grouped = relationship_df.groupby(["source","target"], sort=False, as_index=False).sum()

# %%
relationship_df_grouped
# Out:
#             source          target  value
# 0           france         germany     25
# 1          germany           italy     27
# 2          austria         germany     11
# 3   czechoslovakia          france      6
# 4           france          poland     15
# 5          germany          poland     18
# 6           poland    soviet union     15
# 7          germany    soviet union      6
# 8          germany          latvia      5
# 9          finland          latvia      6
# 10         finland         germany     12
# 11         denmark          poland      6
# 12         denmark          norway     12
# 13         denmark     netherlands      6
# 14          france     netherlands      5
# 15          france           italy      7
# 16          greece      yugoslavia     12
# 17          greece    soviet union      6
# 18           egypt    soviet union      1
# 19           egypt           libya      5
# 20         germany           japan     31
# 21           china           japan     11
# 22           japan       singapore     11
# 23           japan     philippines     12
# 24          guinea           japan     11
# 25          mexico          poland      3
# 26         germany          mexico      6
# 27          france           japan      6
# 28           china          france      6
# 29           china           india     12
# 30           india        pakistan      9
# 31         germany        pakistan      4
# 32           japan    west germany      6
# 33           india      seychelles      6
# 34          angola      seychelles      5
# 35          angola    soviet union      1
# 36         albania    soviet union      5
# 37         albania        bulgaria      6
# 38        bulgaria          poland      6
# 39          poland         romania      6
# 40  czechoslovakia         romania      6
# 41           china  czechoslovakia      5
# 42           china    soviet union      6
# 43          canada    soviet union      3
# 44       australia          canada      6
# 45            cuba   united states      3
# 46    soviet union   united states      6
# 47           japan    soviet union      8
# 48  czechoslovakia      yugoslavia      6
# 49           italy           japan      6
# 50           japan   united states      3
# 51     afghanistan        pakistan      6
# 52           india       singapore      5

# %%
relationship_df_grouped.to_csv('20th_century_countries_relationship.csv')
